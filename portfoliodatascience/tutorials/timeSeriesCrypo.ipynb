# %% [markdown]
# # Analysis of time series data from crytocurrencies markets
# ### Using coinGecko API and Prophet
# Requirements: plotly, prophet, pandas, datetime, requests

# %%
import sys
import pandas as pd
from datetime import datetime
sys.path.insert(0, '../src')

# %% [markdown]
# Define the number of markets and days (historical data) to request:

# %%
numberOfCoins = 10
numberOfDays = 400

# %% [markdown]
# Obtain data from coinGecko API

# %%
from getGeckoData import *
from plotlyTimeSeries import *
listData, priceDf = getGeckoMarket(numberOfCoins, numberOfDays)
datetimeX = pd.to_datetime(priceDf.index.values, unit='ms')
title = 'Time Series Crypto (last ' + str(numberOfDays) + ' days)'
# Out:
# Data obtained from: https://api.coingecko.com/api/v3/
#
# Days considered: 400
#
# Obtaining price for...
# (btc) bitcoin
# (ltc) litecoin
# (aur) auroracoin
# (ppc) peercoin
# (doge) dogecoin
# (nxt) nxt
# (omni) omni
# (nmc) namecoin
# (xcp) counterparty
# (qrk) quark

# %%
plotlyTimeSeries(datetimeX, listData, title, jupyter_notebook = True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <div id="8d127e66-123e-442f-982c-119783c28fa5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8d127e66-123e-442f-982c-119783c28fa5", [{"mode": "markers+lines", "name": "btc", "x": ["2017-10-10 22:00:00", "2017-10-11 22:00:00", "2017-10-12 22:00:00", "2017-10-13 22:00:00", "2017-10-14 22:00:00", "2017-10-15 22:00:00", "2017-10-16 22:00:00", "2017-10-17 22:00:00", "2017-10-18 22:00:00", "2017-10-19 22:00:00", "2017-10-20 22:00:00", "2017-10-21 22:00:00", "2017-10-22 22:00:00", "2017-10-23 22:00:00", "2017-10-24 22:00:00", "2017-10-25 22:00:00", "2017-10-26 22:00:00", "2017-10-27 22:00:00", "2017-10-28 22:00:00", "2017-10-29 23:00:00", "2017-10-30 23:00:00", "2017-10-31 23:00:00", "2017-11-01 23:00:00", "2017-11-02 23:00:00", "2017-11-03 23:00:00", "2017-11-04 23:00:00", "2017-11-05 23:00:00", "2017-11-06 23:00:00", "2017-11-07 23:00:00", "2017-11-08 23:00:00", "2017-11-09 23:00:00", "2017-11-10 23:00:00", "2017-11-11 23:00:00", "2017-11-12 23:00:00", "2017-11-13 23:00:00", "2017-11-14 23:00:00", "2017-11-15 23:00:00", "2017-11-16 23:00:00", "2017-11-17 23:00:00", "2017-11-18 23:00:00", "2017-11-19 23:00:00", "2017-11-20 23:00:00", "2017-11-21 23:00:00", "2017-11-22 23:00:00", "2017-11-23 23:00:00", "2017-11-24 23:00:00", "2017-11-25 23:00:00", "2017-11-26 23:00:00", "2017-11-27 23:00:00", "2017-11-28 23:00:00", "2017-11-29 23:00:00", "2017-11-30 23:00:00", "2017-12-01 23:00:00", "2017-12-02 23:00:00", "2017-12-03 23:00:00", "2017-12-04 23:00:00", "2017-12-05 23:00:00", "2017-12-06 23:00:00", "2017-12-07 23:00:00", "2017-12-08 23:00:00", "2017-12-09 23:00:00", "2017-12