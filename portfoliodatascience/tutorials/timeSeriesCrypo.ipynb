# %% [markdown]
# # Analysis of time series data from crytocurrencies markets
# ### Using coinGecko API and Prophet
# Requirements: plotly, prophet, pandas, datetime, requests

# %%
import sys
import pandas as pd
from datetime import datetime
sys.path.insert(0, '../src')

# %% [markdown]
# Define the number of markets and days (historical data) to request:

# %%
numberOfCoins = 10
numberOfDays = 100

# %% [markdown]
# Obtain data from coinGecko API

# %%
from getGeckoData import *
from plotlyTimeSeries import *
listData, priceDf = getGeckoMarket(numberOfCoins, numberOfDays)
datetimeX = pd.to_datetime(priceDf.index.values, unit='ms')
title = 'Time Series Crypto (last ' + str(numberOfDays) + ' days)'
# Out:
# Data obtained from: https://api.coingecko.com/api/v3/
#
# Days considered: 100
#
# Obtaining price for...
# (btc) bitcoin
# (ltc) litecoin
# (aur) auroracoin
# (ppc) peercoin
# (doge) dogecoin
# (nxt) nxt
# (omni) omni
# (nmc) namecoin
# (xcp) counterparty
# (qrk) quark

# %%
plotlyTimeSeries(datetimeX, listData, title, jupyter_notebook = True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <div id="ab18e85b-02b4-4ca8-9566-007ab6c01c62" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ab18e85b-02b4-4ca8-9566-007ab6c01c62", [{"mode": "markers+lines", "name": "btc", "x": ["2018-08-06 22:00:00", "2018-08-07 22:00:00", "2018-08-08 22:00:00", "2018-08-09 22:00:00", "2018-08-10 22:00:00", "2018-08-11 22:00:00", "2018-08-12 22:00:00", "2018-08-13 22:00:00", "2018-08-14 22:00:00", "2018-08-15 22:00:00", "2018-08-16 22:00:00", "2018-08-17 22:00:00", "2018-08-18 22:00:00", "2018-08-19 22:00:00", "2018-08-20 22:00:00", "2018-08-21 22:00:00", "2018-08-22 22:00:00", "2018-08-23 22:00:00", "2018-08-24 22:00:00", "2018-08-25 22:00:00", "2018-08-26 22:00:00", "2018-08-27 22:00:00", "2018-08-28 22:00:00", "2018-08-29 22:00:00", "2018-08-30 22:00:00", "2018-08-31 22:00:00", "2018-09-01 22:00:00", "2018-09-02 22:00:00", "2018-09-03 22:00:00", "2018-09-04 22:00:00", "2018-09-05 22:00:00", "2018-09-06 22:00:00", "2018-09-07 22:00:00", "2018-09-08 22:00:00", "2018-09-09 22:00:00", "2018-09-10 22:00:00", "2018-09-11 22:00:00", "2018-09-12 22:00:00", "2018-09-13 22:00:00", "2018-09-14 22:00:00", "2018-09-15 22:00:00", "2018-09-16 22:00:00", "2018-09-17 22:00:00", "2018-09-18 22:00:00", "2018-09-19 22:00:00", "2018-09-20 22:00:00", "2018-09-21 22:00:00", "2018-09-22 22:00:00", "2018-09-23 22:00:00", "2018-09-24 22:00:00", "2018-09-25 22:00:00", "2018-09-26 22:00:00", "2018-09-27 22:00:00", "2018-09-28 22:00:00", "2018-09-29 22:00:00", "2018-